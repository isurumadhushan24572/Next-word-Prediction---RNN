# %% [markdown]
# ### import necessary libraries

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### load dataset

# %%
path = "../WebScraping/paragraphs.txt"
with open(path, 'r', encoding='utf-8') as file:
    football_history = file.read()

# %% [markdown]
# ### Reading Text File Content

# %%
football_history
# Out:
# "\n\nWelcome to FootballHistory.org, a website about football history including competitions, teams and players.\n\nFootball (or soccer as the game is called in some parts of the world) has a long history. Football in its current form arose in England in the middle of the 19th century. But alternative versions of the game existed much earlier and are a part of the football history.\n\nThe first known examples of a team game involving a ball, which was made out of a rock, occurred in old Mesoamerican cultures for over 3,000 years ago.  It was by the Aztecs calledTchatali, although various versions of the game were spread over large regions. In some ritual occasions, the ball would symbolize the sun and the captain of the losing team would be sacrificed to the gods. A unique feature of the Mesoamerican ball game versions was a bouncing  ball made of rubber â\x80\x93  no other early culture had access to rubber.The first known ball game which also involved kicking took place In China in the 3rd and 2nd century BC under the namecuju. Cuju was played with a round ball (stitched  leather  with fur or feathers inside) on an area of a square. A modified form of this game  later spread to Japan and was by the name ofkemaripracticed under ceremonial forms.Perhaps even older than cuju wasMarn Gook, played by Aboriginal Australians and according to white emigrants in the 1800s,    a ball game that primarily involving kicking. The ball was made by encased leaves or roots. The rules are mostly unknown, but as with many  other early versions of the game, a chief feature seems to have been to keep  the ball in the air.Other  variety of ball games had been known from  Ancient Greece. The ball was made by shreds of leather filled with hair (the first documents of balls filledÂ\xa0with air are from the 7th century). Ball games had, however, a low status and was not included at the Panhellenic Games. In the Ancient Rome, games with balls were not included in the entertainment on the big arenas (amphitheaters), but  occurred in exercises in the military by the name ofHarpastum. It was the Roman culture that would bring football to the British island (Britannica). It is, however, uncertain in which degree the British people were influenced by this variety and in which degree they had developed their own variants.\n\nThe most admitted story tells that the game was developed in England in the 12th century. In this century, games that resembled  football were played on meadows and roads in England. Besides from kicks, the game involved also punches of the ball with the fist. This early form of football was also much more rough and  violent than the modern way of playing.An important feature of the forerunners to football was that the games  involved plenty of people and took place over large areas in towns (an equivalent was played in Florence from the 16th century where it was calledCalcio). The rampage of these games would cause damage on the town and sometimes death to the participants. These would be among the reasons for the proclamations against the game that finally was forbidden for several centuries. But the football-like games would return to the streets of London in the 17th century. It would be forbidden again in 1835, but at this stage the game had been established in the public schools.\n\nIt took, however, long time until the features of todayâ\x80\x99s football had been taken into practice. For a long time there was no clear distinction between football and rugby. There were also many variations concerning the size of the ball, the number of players and the length of a match.\n\nThe game was often played in schools and two of the predominant schools were Rugby and Eton. At Rugby the rules included the possibility to take up the ball with the hands and the game we today know as rugby has its origin from here. At Eton on the other hand the ball was played exclusively with the feet and this game can  be seen as a close predecessor to the  ...

# %% [markdown]
# ### Tokenizing the text document content

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts([football_history])

# %%
tokenizer.get_config()
# Out:
# {'num_words': None,
#  'filters': '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n',
#  
, "examples": 156, "involving": 157, "mesoamerican": 158, "various": 159, "large": 160, "regions": 161, "rubber": 162, "kicking": 163, "china": 164, "under": 165, "cuju": 166, "round": 167, "leather": 168, "even": 169, "than": 170, "primarily": 171, "air": 172, "variety": 173, "ancient": 174, "balls": 175, "status": 176, "entertainment": 177, "bring": 178, "degree": 179, "developed": 180, "besides": 181, "playing": 182, "areas": 183, "against": 184, "finally": 185, "forbidden": 186, "stage": 187, "public": 188, "distinction": 189, "concerning": 190, "size": 191, "number": 192, "often": 193, "hands": 194, "hand": 195, "can": 196, "\\u00e2\\u0080\\u009cthe": 197, "game\\u00e2\\u0080\\u009d": 198, "while": 199, "event": 200, "divided": 201, "develop": 202, "one": 203, "yet": 204, "development": 205, "run": 206, "working": 207, "america": 208, "interest": 209, "school": 210, "oldest": 211, "larger": 212, "cities": 213, "workers": 214, "join": 215, "start": 216, "only": 217, "1880s": 218, "joined": 219, "competition": 220, "divisions": 221, "participating": 222, "started": 223, "women\'s": 224, "1888": 225, "fa": 226, "following": 227, "0": 228, "f\\u00e3\\u00a9d\\u00e3\\u00a9ration": 229, "internationale": 230, "1950": 231, "leagues": 232, "already": 233, "1930": 234, "sports": 235, "comparison": 236, "park": 237, "few": 238, "built": 239, "stadiums": 240, "stadium": 241, "200": 242, "traditions": 243, "american": 244, "fans": 245, "adopted": 246, "then": 247, "returned": 248, "every": 249, "fourth": 250, "david": 251, "brilliance": 252, "heart": 253, "human": 254, "http": 255, "spartacus": 256, "educational": 257, "htmhttp": 258, "welcome": 259, "footballhistory": 260, "website": 261, "including": 262, "competitions": 263, "current": 264, "arose": 265, "middle": 266, "alternative": 267, "earlier": 268, "out": 269, "rock": 270, "old": 271, "cultures": 272, "3": 273, "ag ...

# %% [markdown]
# ### Get the Each Token index

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'in': 2,
#  'of': 3,
#  'and': 4,
#  'was': 5,
#  'football': 6,
#  'a': 7,
#  'to': 8,
#  'game': 9,
#  'ball': 10,
#  'would': 11,
#  'for': 12,
#  'first': 13,
#  'it': 14,
#  'by': 15,
#  'other': 16,
#  'that': 17,
#  'with': 18,
#  'as': 19,
#  'games': 20,
#  'from': 21,
#  'world': 22,
#  'were': 23,
#  'teams': 24,
#  'but': 25,
#  'be': 26,
#  'century': 27,
#  'played': 28,
#  'british': 29,
#  'is': 30,
#  'on': 31,
#  'this': 32,
#  'not': 33,
#  'time': 34,
#  'cup': 35,
#  'fifa': 36,
#  'players': 37,
#  'long': 38,
#  'england': 39,
#  'which': 40,
#  'at': 41,
#  'association': 42,
#  'history': 43,
#  'has': 44,
#  'are': 45,
#  'had': 46,
#  'an': 47,
#  'more': 48,
#  'sport': 49,
#  'clubs': 50,
#  'also': 51,
#  'been': 52,
#  'included': 53,
#  'people': 54,
#  'rugby': 55,
#  'took': 56,
#  'place': 57,
#  'rules': 58,
#  'national': 59,
#  'de': 60,
#  'about': 61,
#  'some': 62,
#  '19th': 63,
#  'known': 64,
#  '000': 65,
#  'â\x80\x93': 66,
#  'no': 67,
#  'early': 68,
#  'involved': 69,
#  'later': 70,
#  'name': 71,
#  'many': 72,
#  'have': 73,
#  'however': 74,
#  'important': 75,
#  'there': 76,
#  'between': 77,
#  'two': 78,
#  'today': 79,
#  'formed': 80,
#  'year': 81,
#  'com': 82,
#  'or': 83,
#  'its': 84,
#  'versions': 85,
#  'team': 86,
#  'made': 87,
#  'occurred': 88,
#  'over': 89,
#  'established': 90,
#  'until': 91,
#  'into': 92,
#  'meeting': 93,
#  'another': 94,
#  'could': 95,
#  'used': 96,
#  'english': 97,
#  'scottish': 98,
#  'became': 99,
#  'late': 100,
#  'who': 101,
#  'since': 102,
#  'official': 103,
#  'called': 104,
#  'parts': 105,
#  'form': 106,
#  'existed': 107,
#  'much': 108,
#  'years': 109,
#  'spread': 110,
#  'feature': 111,
#  'culture': 112,
#  'white': 113,
#  'big': 114,
#  'arenas': 115,
#  'they': 116,
#  'their': 117,
#  'most': 118,
#  'modern': 119,
#  'these': 120,
#  'sometimes': 121,
#  'among': 122,
#  'london': 123,
#  'schools': 124,
#  'match': 125,
#  'predominant': 126,
#  'eton': 127,
#  'up': 128,
#  'we': 129,
#  'seen': 130,
#  'when': 131,
#  'still': 132,
#  'soon': 133,
#  'matches': 134,
#  'expand': 135,
#  'south': 136,
#  'without': 137,
#  'club': 138,
#  'professional': 139,
#  'level': 140,
#  'league': 141,
#  'women': 142,
#  'scotland': 143,
#  'tournament': 144,
#  'countries': 145,
#  'olympic': 146,
#  'black': 147,
#  'biggest': 148,
#  'global': 149,
#  'associations': 150,
#  'confederation': 151,
#  'www': 152,
#  'org': 153,
#  'soccer': 154,
#  'part': 155,
#  'examples': 156,
#  'involving': 157,
#  'mesoamerican': 158,
#  'various': 159,
#  'large': 160,
#  'regions': 161,
#  'rubber': 162,
#  'kicking': 163,
#  'china': 164,
#  'under': 165,
#  'cuju': 166,
#  'round': 167,
#  'leather': 168,
#  'even': 169,
#  'than': 170,
#  'primarily': 171,
#  'air': 172,
#  'variety': 173,
#  'ancient': 174,
#  'balls': 175,
#  'status': 176,
#  'entertainment': 177,
#  'bring': 178,
#  'degree': 179,
#  'developed': 180,
#  'besides': 181,
#  'playing': 182,
#  'areas': 183,
#  'against': 184,
#  'finally': 185,
#  'forbidden': 186,
#  'stage': 187,
#  'public': 188,
#  'distinction': 189,
#  'concerning': 190,
#  'size': 191,
#  'number': 192,
#  'often': 193,
#  'hands': 194,
#  'hand': 195,
#  'can': 196,
#  'â\x80\x9cthe': 197,
#  'gameâ\x80\x9d': 198,
#  'while': 199,
#  'event': 200,
#  'divided': 201,
#  'develop': 202,
#  'one': 203,
#  'yet': 204,
#  'development': 205,
#  'run': 206,
#  'working': 207,
#  'america': 208,
#  'interest': 209,
#  'school': 210,
#  'oldest': 211,
#  'larger': 212,
#  'cities': 213,
#  'workers': 214,
#  'join': 215,
#  'start': 216,
#  'only': 217,
#  '1880s': 218,
#  'joined': 219,
#  'competition': 220,
#  'divisions': 221,
#  'participating': 222,
#  'started': 223,
#  "women's": 224,
#  '1888': 225,
#  'fa': 226,
#  'following': 227,
#  '0': 228,
#  'fã©dã©ration': 229,
#  'internationale': 230,
#  '1950': 231,
#  'leagues': 232,
#  'already': 233,
#  '1930': 234,
#  'sports': 235,
#  'comparison': 236,
#  'park': 237,
#  'few': 238,
#  'built': 239,
#  'stadiums': 240,
#  'stadium': 241,
#  '200': 242,
#  'traditions': 243,
#  'american': 244,
#  'fans': 245,
#  'adopted': 246,
#  'then': 247,
#  'returned': 248,
#  'every': 249,
#  'fourth': 250,
#  'david': 251,
#  'brilliance': 252,
#  'heart': 253,
#  'human': 254,
#  'http': 255,
#  'spartacus': 256,
#  'educational': 257,
#  'htmhttp': 258,
#  'welcome': 259,
#  'footballhistory': 260,
#  'website': 261,
#  'including': 262,
#  'competitions': 263,
#  'current': 264,
#  'arose': 265,
#  'middle': 266,
#  'alternative': 267,
#  'earlier': 268,
#  'out': 269,
#  'rock': 270,
#  'old': 271,
#  'cultures': 272,
#  '3': 273,
#  'ago': 274,
#  'aztecs': 275,
#  'calledtchatali': 276,
#  'although': 277,
#  'ritual': 278,
#  'occasions': 279,
#  'symbolize': 280,
#  'sun': 281,
#  'captain': 282,
#  'losing': 283,
#  'sacrificed': 284,
#  'gods': 285,
#  'unique': 286,
#  'bouncing': 287,
#  'access': 288,
#  '3rd': 289,
#  '2nd': 290,
#  'bc': 291,
#  'namecuju': 292,
#  'stitched': 293,
#  'fur': 294,
#  'feathers': 295,
#  'inside': 296,
#  'area': 297,
#  'square': 298,
#  'modified': 299,
#  'japan': 300,
#  'ofkemaripracticed': 301,
#  'ceremonial': 302,
#  'forms': 303,
#  'perhaps': 304,
#  'older': 305,
#  'wasmarn': 306,
#  'gook': 307,
#  'aboriginal': 308,
#  'australians': 309,
#  'according': 310,
#  'emigrants': 311,
#  '1800s': 312,
#  'encased': 313,
#  'leaves': 314,
#  'roots': 315,
#  'mostly': 316,
#  'unknown': 317,
#  'chief': 318,
#  'seems': 319,
#  'keep': 320,
#  'greece': 321,
#  'shreds': 322,
#  'filled': 323,
#  'hair': 324,
#  'documents': 325,
#  'filledâ\xa0with': 326,
#  '7th': 327,
#  'low': 328,
#  'panhellenic': 329,
#  'rome': 330,
#  'amphitheaters': 331,
#  'exercises': 332,
#  'military': 333,
#  'ofharpastum': 334,
#  'roman': 335,
#  'island': 336,
#  'britannica': 337,
#  'uncertain': 338,
#  'influenced': 339,
#  'own': 340,
#  'variants': 341,
#  'admitted': 342,
#  'story': 343,
#  'tells': 344,
#  '12th': 345,
#  'resembled': 346,
#  'meadows': 347,
#  'roads': 348,
#  'kicks': 349,
#  'punches': 350,
#  'fist': 351,
#  'rough': 352,
#  'violent': 353,
#  'way': 354,
#  'forerunners': 355,
#  'plenty': 356,
#  'towns': 357,
#  'equivalent': 358,
#  'florence': 359,
#  '16th': 360,
#  'where': 361,
#  'calledcalcio': 362,
#  'rampage': 363,
#  'cause': 364,
#  'damage': 365,
#  'town': 366,
#  'death': 367,
#  'participants': 368,
#  'reasons': 369,
#  'proclamations': 370,
#  'several': 371,
#  'centuries': 372,
#  'like': 373,
#  'return': 374,
#  'streets': 375,
#  '17th': 376,
#  'again': 377,
#  '1835': 378,
#  'features': 379,
#  'todayâ\x80\x99s': 380,
#  'taken': 381,
#  'practice': 382,
#  'clear': 383,
#  'variations': 384,
#  'length': 385,
#  'possibility': 386,
#  'take': 387,
#  'know': 388,
#  'origin': 389,
#  'here': 390,
#  'exclusively': 391,
#  'feet': 392,
#  'close': 393,
#  'predecessor': 394,
#  'running': 395,
#  'dribbling': 396,
#  'attempt': 397,
#  'create': 398,
#  'proper': 399,
#  'done': 400,
#  'cambridge': 401,
#  '1848': 402,
#  'finalâ\xa0solutionâ\xa0to': 403,
#  'all': 404,
#  'questions': 405,
#  'achieved': 406,
#  'came': 407,
#  '1863': 408,
#  'decided': 409,
#  'carrying': 410,
#  "wasn't": 411,
#  'allowed': 412,
#  'alsoâ\xa0resulted': 413,
#  'standardization': 414,
#  'weight': 415,
#  'consequence': 416,
#  'codes': 417,
#  'continue': 418,
#  'flexibility': 419,
#  'thing': 420,
#  'pitch': 421,
#  'vary': 422,
#  'neither': 423,
#  'uniforms': 424,
#  'distinguish': 425,
#  'appearance': 426,
#  'common': 427,
#  'wearing': 428,
#  'caps': 429,
#  'header': 430,
#  'further': 431,
#  'reading': 432,
#  'difference': 433,
#  'noticed': 434,
#  'whereas': 435,
#  'preferred': 436,
#  'forward': 437,
#  'fashion': 438,
#  'chose': 439,
#  'pass': 440,
#  'approach': 441,
#  'class': 442,
#  'unprecedented': 443,
#  'amounts': 444,
#  'spectators': 445,
#  '30': 446,
#  'see': 447,
#  'peoples': 448,
#  'traveled': 449,
#  'result': 450,
#  'colonization': 451,
#  'efforts': 452,
#  'especially': 453,
#  'india': 454,
#  'become': 455,
#  '15th': 456,
#  'unorganized': 457,
#  'therefore': 458,
#  'hard': 459,
#  'decide': 460,
#  'historians': 461,
#  'suggest': 462,
#  'foot': 463,
#  '1824': 464,
#  'edinburgh': 465,
#  'former': 466,
#  'students': 467,
#  'kind': 468,
#  'sheffield': 469,
#  '1855': 470,
#  'clubnotts': 471,
#  'countythat': 472,
#  '1862': 473,
#  'exists': 474,
#  'step': 475,
#  'emergence': 476,
#  'industrialization': 477,
#  'led': 478,
#  'groups': 479,
#  'places': 480,
#  'such': 481,
#  'factories': 482,
#  'pubs': 483,
#  'churches': 484,
#  'new': 485,
#  'railroads': 486,
#  'them': 487,
#  'beginning': 488,
#  'dominated': 489,
#  'consisting': 490,
#  'make': 491,
#  'majority': 492,
#  'change': 493,
#  'successively': 494,
#  'taking': 495,
#  'willing': 496,
#  'pay': 497,
#  'best': 498,
#  'period': 499,
#  'transition': 500,
#  'friction': 501,
#  'motivation': 502,
#  'behind': 503,
#  'paying': 504,
#  'win': 505,
#  'moved': 506,
#  'ahead': 507,
#  'tickets': 508,
#  'sold': 509,
#  '1885': 510,
#  'legalized': 511,
#  'three': 512,
#  'thefootball': 513,
#  'leaguewas': 514,
#  'during': 515,
#  'season': 516,
#  '12': 517,
#  'interested': 518,
#  'consequently': 519,
#  'dominant': 520,
#  'after': 521,
#  'decades': 522,
#  'prague': 523,
#  'budapest': 524,
#  'sienna': 525,
#  'contenders': 526,
#  'dominance': 527,
#  'things': 528,
#  'excluded': 529,
#  'before': 530,
#  'play': 531,
#  'inverness': 532,
#  'milestones': 533,
#  'now': 534,
#  'follow': 535,
#  'challenge': 536,
#  '1871': 537,
#  'ended': 538,
#  'followed': 539,
#  '4': 540,
#  'hamilton': 541,
#  'crescent': 542,
#  'picture': 543,
#  'shows': 544,
#  'illustrations': 545,
#  'occasion': 546,
#  'twelve': 547,
#  '1883': 548,
#  'international': 549,
#  'four': 550,
#  'ireland': 551,
#  'wales': 552,
#  'phenomenon': 553,
#  'gradually': 554,
#  'european': 555,
#  'outside': 556,
#  'europe': 557,
#  'argentina': 558,
#  '1867': 559,
#  'foreign': 560,
#  'argentinean': 561,
#  'citizens': 562,
#  'founded': 563,
#  '1904': 564,
#  'foundation': 565,
#  'act': 566,
#  'signed': 567,
#  'representatives': 568,
#  'france': 569,
#  'belgium': 570,
#  'denmark': 571,
#  'netherlands': 572,
#  'spain': 573,
#  'sweden': 574,
#  'switzerland': 575,
#  'countriesâ\xa0did': 576,
#  'invented': 577,
#  'saw': 578,
#  'reason': 579,
#  'subordinate': 580,
#  'partake': 581,
#  'domestic': 582,
#  'mentioned': 583,
#  'based': 584,
#  'performance': 585,
#  '1908': 586,
#  'rank': 587,
#  'prestigious': 588,
#  'added': 589,
#  '1996': 590,
#  'male': 591,
#  'being': 592,
#  'present': 593,
#  'relatively': 594,
#  'example': 595,
#  'tennis': 596,
#  'traditionally': 597,
#  'mix': 598,
#  'britain': 599,
#  'andrew': 600,
#  'watsonis': 601,
#  'player': 602,
#  'he': 603,
#  'queenâ\x80\x99s': 604,
#  'show': 605,
#  'passion': 606,
#  'extent': 607,
#  'flocked': 608,
#  'shearing': 609,
#  'front': 610,
#  'television': 611,
#  'watching': 612,
#  'carefully': 613,
#  'great': 614,
#  'enthusiasm': 615,
#  'goodison': 616,
#  'purpose': 617,
#  'hosting': 618,
#  '1894': 619,
#  'final': 620,
#  'notts': 621,
#  'county': 622,
#  'bolton': 623,
#  'wanderers': 624,
#  'attended': 625,
#  '37': 626,
#  'milestone': 627,
#  'construction': 628,
#  'maracanã£': 629,
#  'imposing': 630,
#  'rio': 631,
#  'janeiro': 632,
#  'ready': 633,
#  'almost': 634,
#  'capacity': 635,
#  'host': 636,
#  'different': 637,
#  'fan': 638,
#  'tradition': 639,
#  'singing': 640,
#  'repertoire': 641,
#  'inspired': 642,
#  'pub': 643,
#  'songs': 644,
#  'americans': 645,
#  'adopt': 646,
#  'carnival': 647,
#  'style': 648,
#  'firecrackers': 649,
#  'fireworks': 650,
#  'phenomena': 651,
#  'bengali': 652,
#  'fires': 653,
#  'mixture': 654,
#  'summer': 655,
#  'measure': 656,
#  'itself': 657,
#  'thefifa': 658,
#  'edition': 659,
#  'uruguay': 660,
#  'exceptions': 661,
#  'due': 662,
#  'second': 663,
#  'war': 664,
#  '1991': 665,
#  'held': 666,
#  'thechampions': 667,
#  '1992': 668,
#  'formereuropean': 669,
#  '1955â\x80\x931991': 670,
#  'active': 671,
#  'each': 672,
#  '1870s': 673,
#  '211': 674,
#  'governing': 675,
#  'body': 676,
#  'proof': 677,
#  'globalization': 678,
#  'increase': 679,
#  'nations': 680,
#  'qualifiers': 681,
#  '32': 682,
#  '1934': 683,
#  '2014': 684,
#  'six': 685,
#  'confederations': 686,
#  'confã©dã©ration': 687,
#  'africaine': 688,
#  'caf': 689,
#  'asian': 690,
#  'afc': 691,
#  'union': 692,
#  'des': 693,
#  'europã©ennes': 694,
#  'uefa': 695,
#  'north': 696,
#  'central': 697,
#  'caribbean': 698,
#  'concacaf': 699,
#  'oceania': 700,
#  'ofc': 701,
#  'confederaciã³n': 702,
#  'sudamericana': 703,
#  'fãºtbol': 704,
#  'conmebol': 705,
#  'definitely': 706,
#  'quote': 707,
#  "goldblatt's": 708,
#  'bookthe': 709,
#  'roundpresent': 710,
#  'answer': 711,
#  'offers': 712,
#  'spotlight': 713,
#  'individual': 714,
#  'relishing': 715,
#  'defiance': 716,
#  'collective': 717,
#  'endeavor': 718,
#  'staged': 719,
#  'tragedy': 720,
#  'comedy': 721,
#  'epic': 722,
#  'pantomime': 723,
#  'unsophisticated': 724,
#  'music': 725,
#  'hall': 726,
#  'inaccessible': 727,
#  'experimental': 728,
#  'performances': 729,
#  'does': 730,
#  'imperious': 731,
#  'triumph': 732,
#  'lucky': 733,
#  'escapes': 734,
#  'impossible': 735,
#  'comebacks': 736,
#  'stubborn': 737,
#  'stalemates': 738,
#  'captures': 739,
#  'unpredictability': 740,
#  'uncertainty': 741,
#  'skill': 742,
#  'improvisation': 743,
#  'chance': 744,
#  'footballis': 745,
#  '“chess': 746,
#  'green': 747,
#  'pitch”': 748,
#  'united': 749,
#  'states': 750,
#  'canada': 751,
#  'socceris': 752,
#  'instead': 753,
#  'formal': 754,
#  'popular': 755,
#  'speech': 756,
#  'either': 757,
#  '›formations': 758,
#  'systems': 759,
#  'football›the': 760,
#  'evolution': 761,
#  'shoes›the': 762,
#  'field': 763,
#  'dimensions›history': 764,
#  'stadiums›the': 765,
#  'languages›collection': 766,
#  'links': 767,
#  'sites': 768,
#  'web': 769,
#  'references': 770,
#  'encyclopediahistory': 771,
#  'beautiful': 772,
#  '2002': 773,
#  'documentary': 774,
#  'series': 775,
#  'footballâ\x80\x93': 776,
#  'goldblatt': 777,
#  '2008': 778,
#  'https': 779,
#  'en': 780,
#  'wikipedia': 781,
#  'wiki': 782,
#  'clubshttp': 783,
#  'fblack': 784,
#  'fstadiums': 785,
#  'image': 786,
#  'sources': 787,
#  'andrea': 788,
#  'scoto': 789,
#  'itiillustration': 790,
#  'da': 791,
#  'francesco': 792,
#  'bertelli': 793,
#  'paduawilliam': 794,
#  'ralston': 795,
#  '1848â\x80\x931911': 796,
#  'scanned': 797,
#  'bryon': 798,
#  'butler': 799,
#  'queen': 800,
#  'ane': 801,
#  'pressdocumentary': 802,
#  'filmalegria': 803,
#  'do': 804,
#  'povo': 805,
#  '1963': 806}

# %%
input_sequences = []
for sentence in football_history.split('\n'):
    token_list = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(token_list)):
        sequence = token_list[:i+1]
        input_sequences.append(sequence)

# %%
input_sequences[:5]
# Out:
# [[259, 8],
#  [259, 8, 260],
#  [259, 8, 260, 153],
#  [259, 8, 260, 153, 7],
#  [259, 8, 260, 153, 7, 261]]

# %% [markdown]
# ### Get the Maximum length array size

# %%
max_length = max([len(input_sequence) for input_sequence in input_sequences])
max_length
# Out:
# 337

# %% [markdown]
# ### add padding

# %%
input_sequences = np.array(tf.keras.preprocessing.sequence.pad_sequences(input_sequences, maxlen=max_length, padding='pre'))

# %% [markdown]
# ### divide dataset into feature set (X) and labels (y)

# %%
X = input_sequences[:, :-1]
y = input_sequences[:, -1]

# %% [markdown]
# ### number of Unique words

# %%
num_classes = len(tokenizer.word_index)+1

# %% [markdown]
# ### one-hot encoding labels

# %%
y = np.array(tf.keras.utils.to_categorical(y, num_classes=num_classes))

# %% [markdown]
# ### model building

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Embedding(num_classes, 80, input_length=max_length-1)) 
model.add(tf.keras.layers.LSTM(100))
model.add(tf.keras.layers.Dense(num_classes, activation='softmax'))


# num_classes = total unique words or tokens in your dataset
# 80 = embedding dimension
# max_length-1 = input_length
# 100 = number of neurons in LSTM layer
# softmax = activation function for multi-class classification

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 336, 80)           64560
#
#  lstm_1 (LSTM)               (None, 100)               72400
#
#  dense_1 (Dense)             (None, 807)               81507
#
# =================================================================
# Total params: 218467 (853.39 KB)
# Trainable params: 218467 (853.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# model training
epoch = 100
history = model.fit(X, y, epochs=epoch)
# Out:
# Epoch 1/100
# 74/74 [==============================] - 30s 247ms/step - loss: 6.2029 - accuracy: 0.0851
# Epoch 2/100
# 74/74 [==============================] - 19s 254ms/step - loss: 5.7092 - accuracy: 0.0911
# Epoch 3/100
# 74/74 [==============================] - 19s 253ms/step - loss: 5.6232 - accuracy: 0.0911
# Epoch 4/100
# 74/74 [==============================] - 23s 314ms/step - loss: 5.5409 - accuracy: 0.0911
# Epoch 5/100
# 74/74 [==============================] - 24s 320ms/step - loss: 5.4467 - accuracy: 0.0911
# Epoch 6/100
# 74/74 [==============================] - 25s 336ms/step - loss: 5.3268 - accuracy: 0.1064
# Epoch 7/100
# 74/74 [==============================] - 25s 335ms/step - loss: 5.1849 - accuracy: 0.1281
# Epoch 8/100
# 74/74 [==============================] - 34s 462ms/step - loss: 5.0496 - accuracy: 0.1417
# Epoch 9/100
# 74/74 [==============================] - 26s 355ms/step - loss: 4.9251 - accuracy: 0.1468
# Epoch 10/100
# 74/74 [==============================] - 24s 330ms/step - loss: 4.8075 - accuracy: 0.1540
# Epoch 11/100
# 74/74 [==============================] - 26s 351ms/step - loss: 4.6916 - accuracy: 0.1587
# Epoch 12/100
# 74/74 [==============================] - 21s 278ms/step - loss: 4.5798 - accuracy: 0.1689
# Epoch 13/100
# 74/74 [==============================] - 23s 306ms/step - loss: 4.4623 - accuracy: 0.1834
# Epoch 14/100
# 74/74 [==============================] - 24s 319ms/step - loss: 4.3518 - accuracy: 0.1970
# Epoch 15/100
# 74/74 [==============================] - 24s 327ms/step - loss: 4.2364 - accuracy: 0.2140
# Epoch 16/100
# 74/74 [==============================] - 19s 261ms/step - loss: 4.1199 - accuracy: 0.2268
# Epoch 17/100
# 74/74 [==============================] - 24s 319ms/step - loss: 4.0108 - accuracy: 0.2345
# Epoch 18/100
# 74/74 [==============================] - 21s 280ms/step - loss: 3.8955 - accuracy: 0.2477
# Epoch 19/100
# Epoch 78/100
# 74/74 [==============================] - 42s 574ms/step - loss: 0.3611 - accuracy: 0.9609
# Epoch 79/100
# 74/74 [==============================] - 49s 659ms/step - loss: 0.3460 - accuracy: 0.9651
# Epoch 80/100
# 74/74 [==============================] - 36s 484ms/step - loss: 0.3317 - accuracy: 0.9643
# Epoch 81/100
# 74/74 [==============================] - 31s 422ms/step - loss: 0.3176 - accuracy: 0.9668
# Epoch 82/100
# 74/74 [==============================] - 25s 336ms/step - loss: 0.3045 - accuracy: 0.9702
# Epoch 83/100
# 74/74 [==============================] - 23s 305ms/step - loss: 0.2920 - accuracy: 0.9728
# Epoch 84/100
# 74/74 [==============================] - 24s 323ms/step - loss: 0.2793 - accuracy: 0.9740
# Epoch 85/100
# 74/74 [==============================] - 26s 353ms/step - loss: 0.2683 - accuracy: 0.9779
# Epoch 86/100
# 74/74 [==============================] - 24s 319ms/step - loss: 0.2569 - accuracy: 0.9787
# Epoch 87/100
# 74/74 [==============================] - 24s 332ms/step - loss: 0.2442 - accuracy: 0.9796
# Epoch 88/100
# 74/74 [==============================] - 26s 351ms/step - loss: 0.2372 - accuracy: 0.9809
# Epoch 89/100
# 74/74 [==============================] - 20s 269ms/step - loss: 0.2259 - accuracy: 0.9817
# Epoch 90/100
# 74/74 [==============================] - 19s 263ms/step - loss: 0.2151 - accuracy: 0.9830
# Epoch 91/100
# 74/74 [==============================] - 21s 282ms/step - loss: 0.2075 - accuracy: 0.9860
# Epoch 92/100
# 74/74 [==============================] - 22s 294ms/step - loss: 0.1995 - accuracy: 0.9847
# Epoch 93/100
# 74/74 [==============================] - 21s 281ms/step - loss: 0.1889 - accuracy: 0.9872
# Epoch 94/100
# 74/74 [==============================] - 22s 291ms/step - loss: 0.1803 - accuracy: 0.9868
# Epoch 95/100
# 74/74 [==============================] - 23s 309ms/step - loss: 0.1723 - accuracy: 0.9889
# Epoch 96/100
# 74/74 [==============================] - 21s 285ms/step - loss: 0.1661 - accuracy: 0.9894
# Epoch 97/100
# 74/74 [==============================] - 18s 245ms/step - loss: 0.1593 - accuracy: 0.9889
# Epoch 98/100
# 74/74 [==============================] - 19s 253ms/step - loss: 0.1523 - accuracy: 0.9906
# Epoch 99/100
# 74/74 [==============================] - 18s 248ms/step - loss: 0.1457 - accuracy: 0.9923
# Epoch 100/100
# 74/74 [==============================] - 18s 249ms/step - loss: 0.1391 - accuracy: 0.9923

# %%
plt.plot(history.history['accuracy'],label="accuracy")
plt.legend()
plt.title('model accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['loss'],label="loss")
plt.legend()
plt.title('model Loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# ### save the model

# %%
model.save("Next_word_Prediction.h5")
# Out:
# c:\Users\Admin\anaconda3\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### Load the save model

# %%
final_model = tf.keras.models.load_model("./Next_word_Prediction.h5")

# %% [markdown]
# ### Prediction Phase

# %%
no_of_words_predict = 6
input_text = "Football clubs"
for i in range(no_of_words_predict):
    token_list = tokenizer.texts_to_sequences([input_text])[0]
    token_list = tf.keras.preprocessing.sequence.pad_sequences([token_list], maxlen=max_length-1, padding='pre')
    predicted = np.argmax(final_model.predict(token_list), axis=-1)
    output_word = ""
    for word, index in tokenizer.word_index.items():
        if index == predicted:
            output_word = word
            break
    input_text += " " + output_word

print(input_text)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 81ms/step
# Football clubs have existed since the 15th century
